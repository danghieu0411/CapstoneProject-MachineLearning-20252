# %%
# download Dogs vs Cats dataset from Kaggle with kagglehub
# Before running this cell, open the Kaggle competition page and accept the rules.
# !pip -q install kagglehub

import os
import zipfile
import kagglehub
from google.colab import userdata

os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

base_path = kagglehub.competition_download('dogs-vs-cats')
print(f"Downloaded zip file at: {base_path}")

train_zip = os.path.join(base_path, 'train.zip')
test_zip = os.path.join(base_path, 'test1.zip')

print("Unzipping...")

os.makedirs('data', exist_ok=True)

with zipfile.ZipFile(train_zip, 'r') as zip_ref:
  zip_ref.extractall('data')

with zipfile.ZipFile(test_zip, 'r') as zip_ref:
  zip_ref.extractall('data')

print("Success?")
# Out:
# Downloading to /root/.cache/kagglehub/competitions/dogs-vs-cats.archive...
# 100%|██████████| 812M/812M [00:47<00:00, 17.9MB/s]
# Extracting files...
# Downloaded zip file at: /root/.cache/kagglehub/competitions/dogs-vs-cats
# Unzipping...
# Success?

# %%
# import libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

np.random.seed(415)
tf.random.set_seed(415)

# %%
# Kaggle train images are stored in one folder: cat.0.jpg, dog.0.jpg, ...
train_dir = os.path.join('data', 'train')
all_files = sorted([f for f in os.listdir(train_dir) if f.endswith('.jpg')])

cat_files = [f for f in all_files if f.startswith('cat.')]
dog_files = [f for f in all_files if f.startswith('dog.')]

trains = [('cats', os.path.join(train_dir, f)) for f in cat_files]
trains += [('dogs', os.path.join(train_dir, f)) for f in dog_files]

# %%
print('total cat images used:', len(cat_files))
print('total dog images used:', len(dog_files))
print('total images used:', len(trains))
# Out:
# total cat images used: 12500
# total dog images used: 12500
# total images used: 25000

# %%
train_type = ['cats', 'dogs']
print(train_type)
print("Type of train dataset : ", len(train_type))
# Out:
# ['cats', 'dogs']
# Type of train dataset :  2

# %%
train_items, val_items = train_test_split(
    trains,
    test_size=0.2,
    random_state=415,
    stratify=[label for label, path in trains]
)

print("Train images:", len(train_items))
print("Validation images:", len(val_items))
# Out:
# Train images: 20000
# Validation images: 5000

# %%
# train_items and val_items contain (label, image_path) pairs
print(train_items[:5])
# Out:
# [('dogs', 'data/train/dog.10684.jpg'), ('dogs', 'data/train/dog.10757.jpg'), ('dogs', 'data/train/dog.3026.jpg'), ('cats', 'data/train/cat.5154.jpg'), ('cats', 'data/train/cat.11590.jpg')]

# %%
# Build dataframe
trains_df = pd.DataFrame(data=trains, columns=['Pet type', 'Image'])
print(trains_df.head())
print(trains_df.tail())
# Out:
#   Pet type                    Image
# 0     cats     data/train/cat.0.jpg
# 1     cats     data/train/cat.1.jpg
# 2     cats    data/train/cat.10.jpg
# 3     cats   data/train/cat.100.jpg
# 4     cats  data/train/cat.1000.jpg
#       Pet type                    Image
# 24995     dogs  data/train/dog.9995.jpg
# 24996     dogs  data/train/dog.9996.jpg
# 24997     dogs  data/train/dog.9997.jpg
# 24998     dogs  data/train/dog.9998.jpg
# 24999     dogs  data/train/dog.9999.jpg

# %%
# many of sample for each category
print("Total number of pets in the train :", len(trains_df))
# Out:
# Total number of pets in the train : 25000

# %%
pet_count = trains_df['Pet type'].value_counts()

print("print each category: ")
print(pet_count)
# Out:
# print each category:
# Pet type
# cats    12500
# dogs    12500
# Name: count, dtype: int64

# %%
print(cat_files[:10])
print(dog_files[:10])
# Out:
# ['cat.0.jpg', 'cat.1.jpg', 'cat.10.jpg', 'cat.100.jpg', 'cat.1000.jpg', 'cat.10000.jpg', 'cat.10001.jpg', 'cat.10002.jpg', 'cat.10003.jpg', 'cat.10004.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.1000.jpg', 'dog.10000.jpg', 'dog.10001.jpg', 'dog.10002.jpg', 'dog.10003.jpg', 'dog.10004.jpg']

# %%
im_size = 64
batch_size = 32

label_to_index = {'cats': 0, 'dogs': 1}
index_to_label = {0: 'cats', 1: 'dogs'}

train_paths = [path for label, path in train_items]
train_y = np.array([label_to_index[label] for label, path in train_items])
val_paths = [path for label, path in val_items]
val_y = np.array([label_to_index[label] for label, path in val_items])

def load_image(path, label):
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [im_size, im_size])
  img = tf.cast(img, tf.float32) / 255.0
  return img, label

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_y))
train_ds = train_ds.shuffle(1000, seed=415).map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_y))
val_ds = val_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print("Train images:", len(train_paths))
print("Validation images:", len(val_paths))
print("Batch size:", batch_size)
# Out:
# Train images: 20000
# Validation images: 5000
# Batch size: 32

# %%
for sample_images, sample_labels in train_ds.take(1):
  print(sample_images.shape)
  print(sample_labels.shape)
# Out:
# (32, 64, 64, 3)
# (32,)

# %%
print("Train labels sample:", train_y[:5])
print("Validation labels sample:", val_y[:5])
# Out:
# Train labels sample: [1 1 1 0 0]
# Validation labels sample: [0 1 1 0 1]

# %%
print("shape of y_train:", train_y.shape)
print("shape of y_val:", val_y.shape)
# Out:
# shape of y_train: (20000,)
# shape of y_val: (5000,)

# %%
plt.figure(figsize=(15, 4))
for i in range(10):
  plt.subplot(2, 5, i + 1)
  plt.imshow(sample_images[i])
  plt.title(index_to_label[int(sample_labels[i])])
  plt.axis('off')

# %% [markdown]
# # **ARTIFICIAL NEURAL NETWORK**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.RandomFlip("horizontal", input_shape=(im_size, im_size, 3)),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.05),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(
        256,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.0005)
    ),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(2, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 64, 64, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     3,145,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,146,498 (12.00 MB)
#  Trainable params: 3,146,498 (12.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

class BestValAccuracyCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best = -np.inf

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_accuracy = logs.get('val_accuracy')
        if val_accuracy is not None and val_accuracy > self.best:
            self.best = val_accuracy
            self.model.save(self.filepath)
            print(f"\nEpoch {epoch + 1}: val_accuracy improved to {val_accuracy:.4f}. Updated {self.filepath}")

checkpoint = BestValAccuracyCheckpoint('best_ann_model.keras')

history = model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    callbacks=[reduce_lr, checkpoint]
)
# Out:
# Epoch 1/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5358 - loss: 0.9530
# Epoch 1: val_accuracy improved to 0.5658. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.5511 - loss: 0.8947 - val_accuracy: 0.5658 - val_loss: 0.8457 - learning_rate: 1.0000e-04
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5885 - loss: 0.8251
# Epoch 2: val_accuracy improved to 0.5938. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 31ms/step - accuracy: 0.5824 - loss: 0.8156 - val_accuracy: 0.5938 - val_loss: 0.7938 - learning_rate: 1.0000e-04
# Epoch 3/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5922 - loss: 0.7820
# Epoch 3: val_accuracy improved to 0.5984. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.5918 - loss: 0.7734 - val_accuracy: 0.5984 - val_loss: 0.7564 - learning_rate: 1.0000e-04
# Epoch 4/30
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6018 - loss: 0.7469
# Epoch 4: val_accuracy improved to 0.6192. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.5983 - loss: 0.7426 - val_accuracy: 0.6192 - val_loss: 0.7238 - learning_rate: 1.0000e-04
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6056 - loss: 0.7241
# Epoch 5: val_accuracy improved to 0.6208. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6032 - loss: 0.7194 - val_accuracy: 0.6208 - val_loss: 0.7069 - learning_rate: 1.0000e-04
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.6035 - loss: 0.7041 - val_accuracy: 0.5924 - val_loss: 0.7000 - learning_rate: 1.0000e-04
# Epoch 7/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6047 - loss: 0.6928
# Epoch 7: val_accuracy improved to 0.6228. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6078 - loss: 0.6896 - val_accuracy: 0.6228 - val_loss: 0.6810 - learning_rate: 1.0000e-04
# Epoch 8/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6103 - loss: 0.6800
# Epoch 8: val_accuracy improved to 0.6252. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6094 - loss: 0.6795 - val_accuracy: 0.6252 - val_loss: 0.6697 - learning_rate: 1.0000e-04
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6119 - loss: 0.6689 - val_accuracy: 0.6248 - val_loss: 0.6630 - learning_rate: 1.0000e-04
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6176 - loss: 0.6641 - val_accuracy: 0.6176 - val_loss: 0.6633 - learning_rate: 1.0000e-04
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6162 - loss: 0.6637 - val_accuracy: 0.6172 - val_loss: 0.6565 - learning_rate: 1.0000e-04
# Epoch 12/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6177 - loss: 0.6617
# Epoch 12: val_accuracy improved to 0.6302. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6165 - loss: 0.6619 - val_accuracy: 0.6302 - val_loss: 0.6598 - learning_rate: 1.0000e-04
# Epoch 13/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6187 - loss: 0.6590
# Epoch 13: val_accuracy improved to 0.6314. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.6186 - loss: 0.6592 - val_accuracy: 0.6314 - val_loss: 0.6557 - learning_rate: 1.0000e-04
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.6212 - loss: 0.6561 - val_accuracy: 0.6260 - val_loss: 0.6520 - learning_rate: 1.0000e-04
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6221 - loss: 0.6578
# Epoch 15: val_accuracy improved to 0.6330. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6202 - loss: 0.6560 - val_accuracy: 0.6330 - val_loss: 0.6514 - learning_rate: 1.0000e-04
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6179 - loss: 0.6572 - val_accuracy: 0.6258 - val_loss: 0.6544 - learning_rate: 1.0000e-04
# Epoch 17/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6232 - loss: 0.6560
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 17: val_accuracy improved to 0.6338. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.6211 - loss: 0.6553 - val_accuracy: 0.6338 - val_loss: 0.6538 - learning_rate: 1.0000e-04
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6353 - loss: 0.6499 - val_accuracy: 0.6254 - val_loss: 0.6475 - learning_rate: 5.0000e-05
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6287 - loss: 0.6485 - val_accuracy: 0.6300 - val_loss: 0.6483 - learning_rate: 5.0000e-05
# Epoch 20/30
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6287 - loss: 0.6495
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6319 - loss: 0.6480 - val_accuracy: 0.6252 - val_loss: 0.6476 - learning_rate: 5.0000e-05
# Epoch 21/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6391 - loss: 0.6467
# Epoch 21: val_accuracy improved to 0.6376. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6368 - loss: 0.6453 - val_accuracy: 0.6376 - val_loss: 0.6431 - learning_rate: 2.5000e-05
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.6375 - loss: 0.6420 - val_accuracy: 0.6360 - val_loss: 0.6434 - learning_rate: 2.5000e-05
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6397 - loss: 0.6445
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 23: val_accuracy improved to 0.6396. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6403 - loss: 0.6428 - val_accuracy: 0.6396 - val_loss: 0.6451 - learning_rate: 2.5000e-05
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6362 - loss: 0.6429 - val_accuracy: 0.6390 - val_loss: 0.6433 - learning_rate: 1.2500e-05
# Epoch 25/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6426 - loss: 0.6423
# Epoch 25: val_accuracy improved to 0.6438. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6411 - loss: 0.6402 - val_accuracy: 0.6438 - val_loss: 0.6426 - learning_rate: 1.2500e-05
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.6433 - loss: 0.6401 - val_accuracy: 0.6426 - val_loss: 0.6427 - learning_rate: 1.2500e-05
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6454 - loss: 0.6395 - val_accuracy: 0.6414 - val_loss: 0.6421 - learning_rate: 1.2500e-05
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6442 - loss: 0.6408
# Epoch 28: val_accuracy improved to 0.6452. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 35ms/step - accuracy: 0.6434 - loss: 0.6388 - val_accuracy: 0.6452 - val_loss: 0.6412 - learning_rate: 1.2500e-05
# Epoch 29/30
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6476 - loss: 0.6374
# Epoch 29: val_accuracy improved to 0.6464. Updated best_ann_model.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6474 - loss: 0.6377 - val_accuracy: 0.6464 - val_loss: 0.6410 - learning_rate: 1.2500e-05
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6383 - loss: 0.6396 - val_accuracy: 0.6444 - val_loss: 0.6409 - learning_rate: 1.2500e-05

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

best_model = tf.keras.models.load_model('best_ann_model.keras')

val_loss, val_acc = best_model.evaluate(val_ds)
print("Best validation accuracy:", val_acc)
print("Best validation loss:", val_loss)

y_pred = best_model.predict(val_ds)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report:")
print(classification_report(val_y, y_pred_classes, target_names=['cats', 'dogs']))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.6464 - loss: 0.6410
# Best validation accuracy: 0.646399974822998
# Best validation loss: 0.6410443186759949
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         cats       0.64      0.68      0.66      2500
#         dogs       0.66      0.61      0.63      2500
#
#     accuracy                           0.65      5000
#    macro avg       0.65      0.65      0.65      5000
# weighted avg       0.65      0.65      0.65      5000

# %%
cm = confusion_matrix(val_y, y_pred_classes)

fig, ax = plt.subplots(figsize=(5, 4))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['cats', 'dogs']
)
disp.plot(
    cmap=plt.cm.Blues,
    values_format='d',
    ax=ax,
    colorbar=True
)
ax.set_title('Confusion Matrix')
ax.set_xlabel('Predicted label')
ax.set_ylabel('True label')
plt.show()
